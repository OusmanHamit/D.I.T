# %%
import pandas as pd 
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
notes = pd.DataFrame(
            {'Groupe_A': [12, 14, 13, 16, 17, 18, 15, 11, 9, 10, 11, 13, 16, 17, 15, 12, 13, 14, 15, 16],
             'Groupe_B': [10, 11, 12, 13, 14, 14, 14, 13, 11, 12, 13, 14, 14, 15, 16, 17, 18, 19, 20, 20]})

# %%
plt.figure(figsize=(14, 4))
sns.boxplot(data = notes)
plt.show()

# %%
plt.figure(figsize=(14, 4))
sns.boxplot(data = notes, orient='h')
plt.show()

# %%
notes['Groupe_A'].median()
# Out:
# 14.0

# %%
notes['Groupe_B'].median()
# Out:
# 14.0
